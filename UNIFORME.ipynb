# %% [markdown]
# ## Distribucion uniforme

# %% [markdown]
# Simulación de una distribución uniforme

# %%
runif(10,900,1000)
# Out:
#  [1] 913.2338 905.1433 953.0323 980.0418 947.9548 975.8230 988.0244 985.7720
#  [9] 948.2794 989.3921

# %% [markdown]
# Vamos a "fijar la semilla aleatoria"

# %%
set.seed(123)

# %%
runif(10,900,1000)
# Out:
#  [1] 928.7578 978.8305 940.8977 988.3017 994.0467 904.5556 952.8105 989.2419
#  [9] 955.1435 945.6615

# %% [markdown]
# Se concatena y se asigna a la variable x

# %%
x <- c(0.00096264341890935,0.179147941609448,0.939454629989087,0.413966226584262,0.530370201696814,0.931979918355113,0.786487794381794,0.500360174803231,0.553457917903298,0.967226200721798,0.170755531252714,0.888213764358411,0.20873757182096,0.252369594877758,0.575781110476601,0.153123780224996,0.551374241500801,0.946876903971134,0.160125042852073,0.221595214783026,0.350774858310248,0.473043620341012,0.444127071389988,0.443688851522137,0.0785275325544772,0.812239643098898,0.311681563179792,0.432032362759128,0.167920892670714,0.246443116686513)

# %%
options (repr.plot.width=6, repr.plot.height=6/1.61803)
hist(x, col="blue", main="Distribución uniforme")
# Out:
# Plot with title “Distribución uniforme”

# %%
options (repr.plot.width=6, repr.plot.height=6/1.61803)
hist(runif(7e6,),main="Distribución uniforme para 7 millones de números", col="green")
# Out:
# Plot with title “Distribución uniforme para 7 millones de números”

# %% [markdown]
# Simulando la distribución uniforme para los números del melate

# %%
m <- runif(6*2*52*7,1,44)

# %%
options (repr.plot.width=6, repr.plot.height=6/1.61803)
hist(m, col="yellow")
# Out:
# Plot with title “Histogram of m”
